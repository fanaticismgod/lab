# %% [markdown]
# <a href="https://colab.research.google.com/github/fanaticismgod/lab/blob/main/lab2704.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
V = 64 #n^3
p = 101330 #pa
T = 273 #K
R = 8.3145 #j/K*mol
M = (0.012 + 0.001 * 4) #kg/mol
m = (p * V * M) / (R * T)
print(m)
# Out:
# 45.71294642375284

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 45.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import CoolProp.CoolProp as ct
import matplotlib.pyplot as plt
V = 64 
p = 101330
T = 273
R = 8.3145
M = (0.012 + 0.001 * 4)

q = 1

T = np.linspace(0,600,50000)
d = ct.PropsSI('D', 'T', T, 'P', p, 'Methane')
T1 = ct.PropsSI('T', 'P', p, 'Q', q, 'Methane')
plt.plot(T,d*V)
plt.title('d от T')
plt.xlabel('Температура T, K')
plt.ylabel('масса m, kg')
plt.scatter(111.667, 0, color = 'green')
plt.grid()
plt.show()
